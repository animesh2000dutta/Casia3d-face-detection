# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Xtrain=[]
Xtest=[]
ytrain=[]
ytest=[]
for i in range(0,123):
    d=str(i+1)+'/'
    imglist=os.listdir(d)
    l=len(imglist)
    for j in range(l):
        im=cv2.imread(d+imglist[j],)
        if j==0 or j==l-1:
            Xtest.append(im)
            ytest.append(i)
        else:
            Xtrain.append(im)
            ytrain.append(i)

Xtrain=np.array(Xtrain)
Xtest=np.array(Xtest)
ytrain=np.array(ytrain)
ytest=np.array(ytest)

Xtrain=Xtrain/255
Xtest=Xtest/255

Xtrain.shape
# Out:
# (4305, 100, 100, 3)

# %%
Xtest.shape
# Out:
# (246, 100, 100, 3)

# %%
ytrain.shape
# Out:
# (4305,)

# %%
ytest.shape
# Out:
# (246,)

# %%
plt.imshow(Xtrain[4304])

# %%
ytrain[4304]
# Out:
# 122

# %%
plt.imshow(Xtrain[245])

# %%
ytest[245]
# Out:
# 122

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from sklearn.metrics import confusion_matrix,classification_report
from tensorflow.keras.layers import Input,Dense,Conv2D,Flatten,MaxPooling2D
from tensorflow.keras.applications import DenseNet201

# %%
base_model=DenseNet201(weights='imagenet',include_top=False,input_tensor=Input(shape=(100,100,3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 8s 0us/step

# %%
for layer in base_model.layers[:-10]:
    layer.trainable=False

# %%
model=Sequential()

model.add(base_model)

model.add(Flatten())

model.add(Dense(250,activation='relu'))

model.add(Dense(123,activation='softmax'))

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 3, 3, 1920)        18321984
#
#  flatten_5 (Flatten)         (None, 17280)             0
#
#  dense_10 (Dense)            (None, 250)               4320250
#
#  dense_11 (Dense)            (None, 123)               30873
#
# =================================================================
# Total params: 22673107 (86.49 MB)
# Trainable params: 4637523 (17.69 MB)
# Non-trainable params: 18035584 (68.80 MB)
# _________________________________________________________________

# %%
model.fit(Xtrain,ytrain,epochs=10,validation_data=(Xtest,ytest))
# Out:
# Epoch 1/10
# 135/135 [==============================] - 99s 651ms/step - loss: 4.5616 - accuracy: 0.0606 - val_loss: 3.1998 - val_accuracy: 0.2398
# Epoch 2/10
# 135/135 [==============================] - 84s 626ms/step - loss: 2.8815 - accuracy: 0.3252 - val_loss: 1.3753 - val_accuracy: 0.6667
# Epoch 3/10
# 135/135 [==============================] - 85s 633ms/step - loss: 1.8362 - accuracy: 0.5505 - val_loss: 0.7841 - val_accuracy: 0.8089
# Epoch 4/10
# 135/135 [==============================] - 86s 640ms/step - loss: 1.3502 - accuracy: 0.6532 - val_loss: 0.6155 - val_accuracy: 0.8577
# Epoch 5/10
# 135/135 [==============================] - 84s 623ms/step - loss: 0.9920 - accuracy: 0.7445 - val_loss: 0.5483 - val_accuracy: 0.8618
# Epoch 6/10
# 135/135 [==============================] - 84s 624ms/step - loss: 0.7461 - accuracy: 0.8125 - val_loss: 0.4682 - val_accuracy: 0.8862
# Epoch 7/10
# 135/135 [==============================] - 83s 613ms/step - loss: 0.5495 - accuracy: 0.8604 - val_loss: 0.4444 - val_accuracy: 0.9065
# Epoch 8/10
# 135/135 [==============================] - 82s 609ms/step - loss: 0.4041 - accuracy: 0.8980 - val_loss: 0.3439 - val_accuracy: 0.9228
# Epoch 9/10
# 135/135 [==============================] - 82s 609ms/step - loss: 0.2918 - accuracy: 0.9240 - val_loss: 0.3960 - val_accuracy: 0.9024
# Epoch 10/10
# 135/135 [==============================] - 82s 609ms/step - loss: 0.2474 - accuracy: 0.9375 - val_loss: 0.3727 - val_accuracy: 0.9146

# %%
yprob=model.predict(Xtest)
yprob.shape
# Out:
# 8/8 [==============================] - 8s 564ms/step
# (246, 123)

# %%
ypred=yprob.argmax(axis=1)
ypred.shape
# Out:
# (246,)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       0.67      1.00      0.80         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       0.50      0.50      0.50         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      0.50      0.67         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      0.50      0.67         2
#           23       1.00      1.00      1.00         2
#           24       0.67      1.00      0.80         2
#           25       1.00      0.50      0.67         2
#           26       1.00      1.00      1.00         2
#           27       0.67      1.00      0.80         2
#           28       1.00      1.00      1.00         2
#           29       0.67      1.00      0.80         2
#           30       1.00      1.00      1.00         2
#           31       1.00      1.00      1.00         2
#           32       1.00      1.00      1.00         2
#           33       1.00      1.00      1.00         2
#           34       1.00      1.00      1.00         2
#           35       1.00      0.50      0.67         2
#           36       0.67      1.00      0.80         2
#           37       1.00      1.00      1.00         2
#           38       0.67      1.00      0.80         2
#           39       1.00      0.50      0.67         2
#           40       1.00      1.00      1.00         2
#           41       1.00      1.00      1.00         2
#           42       1.00      1.00      1.00         2
#           43       1.00      1.00      1.00         2
#           44       1.00      1.00      1.00         2
#           45       1.00      0.50      0.67         2
#           46       1.00      0.50      0.67         2
#           47       0.67      1.00      0.80         2
#           48       1.00      1.00      1.00         2
#           49       1.00      1.00      1.00         2
#           50       1.00      1.00      1.00         2
#           51       1.00      0.50      0.67         2
#           52       1.00      1.00      1.00         2
#           53       1.00      1.00      1.00         2
#           54       1.00      1.00      1.00         2
#           55       0.40      1.00      0.57         2
#           56       1.00      0.50      0.67         2
#           57       1.00      1.00      1.00         2
#           58       1.00      0.50      0.67         2
#           59       1.00      1.00      1.00         2
#           60       1.00      1.00      1.00         2
#           61       1.00      0.50      0.67         2
#           62       1.00      1.00      1.00         2
#           63       1.00      1.00      1.00         2
#           64       1.00      1.00      1.00         2
#           65       1.00      1.00      1.00         2
#           66       0.67      1.00      0.80         2
#           67       1.00      1.00      1.00         2
#           68       1.00      0.50      0.67         2
#           69       0.67      1.00      0.80         2
#           70       0.00      0.00      0.00         2
#           71       1.00      1.00      1.00         2
#           72       1.00      1.00      1.00         2
#           73       1.00      0.50      0.67         2
#           74       1.00      1.00      1.00         2
#           75       1.00      1.00      1.00         2
#           76       0.67      1.00      0.80         2
#           77       1.00      1.00      1.00         2
#           78       1.00      1.00      1.00         2
#           79       1.00      1.00      1.00         2
#           80       1.00      1.00      1.00         2
#           81       1.00      1.00      1.00         2
#           82       1.00      1.00      1.00         2
#           83       1.00      1.00      1.00         2
#           84       0.67      1.00      0.80         2
#           85       1.00      1.00      1.00         2
#           86       1.00      1.00      1.00         2
#           87       0.50      0.50      0.50         2
#           88       1.00      1.00      1.00         2
#           89       1.00      1.00      1.00         2
#           90       0.67      1.00      0.80         2
#           91       1.00      1.00      1.00         2
#           92       1.00      0.50      0.67         2
#           93       1.00      0.50      0.67         2
#           94       1.00      1.00      1.00         2
#           95       1.00      1.00      1.00         2
#           96       1.00      1.00      1.00         2
#           97       1.00      1.00      1.00         2
#           98       1.00      1.00      1.00         2
#           99       1.00      1.00      1.00         2
#          100       1.00      1.00      1.00         2
#          101       1.00      1.00      1.00         2
#          102       1.00      1.00      1.00         2
#          103       1.00      1.00      1.00         2
#          104       1.00      1.00      1.00         2
#          105       1.00      0.50      0.67         2
#          106       1.00      1.00      1.00         2
#          107       1.00      0.50      0.67         2
#          108       1.00      1.00      1.00         2
#          109       1.00      1.00      1.00         2
#          110       1.00      1.00      1.00         2
#          111       1.00      1.00      1.00         2
#          112       0.67      1.00      0.80         2
#          113       1.00      1.00      1.00         2
#          114       1.00      1.00      1.00         2
#          115       0.50      1.00      0.67         2
#          116       1.00      1.00      1.00         2
#          117       1.00      1.00      1.00         2
#          118       1.00      1.00      1.00         2
#          119       1.00      1.00      1.00         2
#          120       1.00      1.00      1.00         2
#          121       1.00      1.00      1.00         2
#          122       1.00      1.00      1.00         2
#
#     accuracy                           0.91       246
#    macro avg       0.94      0.91      0.91       246
# weighted avg       0.94      0.91      0.91       246
# C:\Users\PRISM WHITE\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\PRISM WHITE\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\PRISM WHITE\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conm=confusion_matrix(ytest,ypred)
plt.figure(figsize=(15,12))
sns.heatmap(data=conm)
plt.plot()
# Out:
# []
